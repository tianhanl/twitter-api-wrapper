# %%
import twitter

# %%
tentativeList = twitter.search_multiple_times(query = 'state of the union', language='en', interval=50000, times=10)

# %%
tentativeList[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 06 03:24:07 +0000 2018',
#  'entities': {'hashtags': [],
#   'media': [{'display_url': 'pic.twitter.com/9mcli9lcXZ',
#     'expanded_url': 'https://twitter.com/WCMUNews/status/960715703648075776/photo/1',
#     'id': 960715700410073094,
#     'id_str': '960715700410073094',
#     'indices': [95, 118],
#     'media_url': 'http://pbs.twimg.com/media/DVUl1uUVQAYbvpQ.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DVUl1uUVQAYbvpQ.jpg',
#     'sizes': {'large': {'h': 450, 'resize': 'fit', 'w': 800},
#      'medium': {'h': 450, 'resize': 'fit', 'w': 800},
#      'small': {'h': 383, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'type': 'photo',
#     'url': 'https://t.co/9mcli9lcXZ'}],
#   'symbols': [],
#   'urls': [{'display_url': 'bit.ly/2nJR2ZG',
#     'expanded_url': 'http://bit.ly/2nJR2ZG',
#     'indices': [71, 94],
# ...

# %%
tentativeList
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue Feb 06 03:24:07 +0000 2018',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/9mcli9lcXZ',
#      'expanded_url': 'https://twitter.com/WCMUNews/status/960715703648075776/photo/1',
#      'id': 960715700410073094,
#      'id_str': '960715700410073094',
#      'indices': [95, 118],
#      'media_url': 'http://pbs.twimg.com/media/DVUl1uUVQAYbvpQ.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DVUl1uUVQAYbvpQ.jpg',
#      'sizes': {'large': {'h': 450, 'resize': 'fit', 'w': 800},
#       'medium': {'h': 450, 'resize': 'fit', 'w': 800},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/9mcli9lcXZ'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/2nJR2ZG',
#      'expanded_url': 'http://bit.ly/2nJR2ZG',
#      'indices': [71, 94],
# ...
